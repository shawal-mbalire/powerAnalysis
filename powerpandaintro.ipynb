# %% [markdown]
# Install pandapower through pip:

# %%
! pip install deep pandapower
# Out:
# Requirement already satisfied: deep in c:\python312\lib\site-packages (0.10)
# Requirement already satisfied: pandapower in c:\python312\lib\site-packages (2.13.1)
# Requirement already satisfied: pandas>=1.0 in c:\python312\lib\site-packages (from pandapower) (2.2.1)
# Requirement already satisfied: networkx>=2.5 in c:\python312\lib\site-packages (from pandapower) (3.2.1)
# Requirement already satisfied: scipy in c:\python312\lib\site-packages (from pandapower) (1.12.0)
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (from pandapower) (1.26.4)
# Requirement already satisfied: packaging in c:\users\shawal\appdata\roaming\python\python312\site-packages (from pandapower) (23.2)
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (from pandapower) (4.66.2)
# Requirement already satisfied: deepdiff in c:\python312\lib\site-packages (from pandapower) (6.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shawal\appdata\roaming\python\python312\site-packages (from pandas>=1.0->pandapower) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas>=1.0->pandapower) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.0->pandapower) (2024.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in c:\python312\lib\site-packages (from deepdiff->pandapower) (4.1.0)
# Requirement already satisfied: colorama in c:\users\shawal\appdata\roaming\python\python312\site-packages (from tqdm->pandapower) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\shawal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.0->pandapower) (1.16.0)

# %% [markdown]
# Create a simple network

# %%
import pandapower as pp
net = pp.create_empty_network() 
b1 = pp.create_bus(net, vn_kv=20.)
b2 = pp.create_bus(net, vn_kv=20.)
pp.create_line(net, from_bus=b1, to_bus=b2, length_km=2.5, std_type="NAYY 4x50 SE")   
pp.create_ext_grid(net, bus=b1)
pp.create_load(net, bus=b2, p_mw=1.)
# Out:
# 0

# %% [markdown]
# Run a power flow:

# %%
pp.runpp(net)
# Out:
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)

# %% [markdown]
# And check the results:

# %%
print(net.res_bus.vm_pu)
print(net.res_line.loading_percent)
# Out:
# 0    1.000000
# 1    0.995988
# Name: vm_pu, dtype: float64
# 0    20.454524
# Name: loading_percent, dtype: float64

# %% [markdown]
# import pandapower.networks
# net = pandapower.networks.example_simple()

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.49.0-cp312-cp312-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.3 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/162.3 kB 445.2 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/162.3 kB 550.5 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/162.3 kB 731.4 kB/s eta 0:00:01
#      ------------------------------------ 162.3/162.3 kB 813.1 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shawal\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shawal\appdata\roaming\python\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shawal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.3-cp312-cp312-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.6 MB 6.4 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/7.6 MB 2.5 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/7.6 MB 3.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/7.6 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/7.6 MB 4.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.6 MB 4.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.6 MB 5.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.6 MB 5.9 MB/s eta 0:00:01
#    ------------- -------------------------- 2.5/7.6 MB 6.4 MB/s eta 0:00:01
#    --------------- ------------------------ 3.0/7.6 MB 6.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.6 MB 7.0 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.6 MB 7.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.4/7.6 MB 7.7 MB/s eta 0:00:01
#    ------------------------- -------------- 4.9/7.6 MB 7.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.6 MB 8.1 MB/s eta 0:00:01
#    ------------------------------ --------- 5.9/7.6 MB 8.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.4/7.6 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.8/7.6 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.4/7.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 8.3 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp312-cp312-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.7 kB ? eta -:--:--
#    --------------------------------------- 187.7/187.7 kB 11.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.49.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------- ----------------------------- 0.6/2.2 MB 11.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.2 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 10.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Python312\\share'
# Consider using the `--user` option or check the permissions.

# %%
from pandapower.plotting import cmap_discrete, create_line_collection, draw_collections
from pandapower.networks import mv_oberrhein
net = mv_oberrhein("generation")
cmap_list = [((0, 10), "green"), ((10, 30), "yellow"), ((30, 100), "red")]
cmap, norm = cmap_discrete(cmap_list)
lc = create_line_collection(net, cmap=cmap, norm=norm)
draw_collections([lc])
# Out:
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\networks\mv_oberrhein.py:79: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   net.trafo.tap_pos.loc[hv_trafos] = [0, 0]
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
# <Axes: >

# %%
from pandapower.plotting import cmap_continuous, create_bus_collection, draw_collections
from pandapower.networks import mv_oberrhein
net = mv_oberrhein("generation")
cmap_list = [(0.97, "blue"), (1.0, "green"), (1.03, "red")]
cmap, norm = cmap_continuous(cmap_list)
bc = create_bus_collection(net, size=70, cmap=cmap, norm=norm)
draw_collections([bc])
# Out:
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\networks\mv_oberrhein.py:79: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   net.trafo.tap_pos.loc[hv_trafos] = [0, 0]
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
# <Axes: >

# %%
from pandapower.plotting import cmap_logarithmic, create_bus_collection, draw_collections
from pandapower.networks import mv_oberrhein
net = mv_oberrhein("generation")
min_value, max_value = 1.0, 1.03
colors = ["blue", "green", "red"]
cmap, norm = cmap_logarithmic(min_value, max_value, colors)
bc = create_bus_collection(net, size=70, cmap=cmap, norm=norm)
draw_collections([bc])
# Out:
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\networks\mv_oberrhein.py:79: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   net.trafo.tap_pos.loc[hv_trafos] = [0, 0]
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
# <Axes: >

# %%
from pandapower.plotting.plotly import simple_plotly
from pandapower.networks import mv_oberrhein
net = mv_oberrhein()
simple_plotly(net)
# Out:
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# c:\Python312\Lib\site-packages\pandapower\networks\mv_oberrhein.py:75: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   net.trafo.tap_pos.loc[hv_trafos] = [-2, -3]
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 from pandapower.networks import mv_oberrhein
#       3 net = mv_oberrhein()
# ----> 4 simple_plotly(net)
#
# File c:\Python312\Lib\site-packages\pandapower\plotting\plotly\simple_plotly.py:146, in simple_plotly(net, respect_switches, use_line_geodata, on_map, projection, map_style, figsize, aspectratio, line_width, bus_size, ext_grid_size, bus_color, line_color, trafo_color, trafo3w_color, ext_grid_color, filename, auto_open, showlegend, additional_traces)
#     144 trans3w_element = "trafo3w"
#     145 separator_element = "switch"
# --> 146 traces, settings = _simple_plotly_generic(net=net,
#     147                                           respect_separators=respect_switches,
#     148                                           use_branch_geodata=use_line_geodata,
#     149                                           on_map=on_map,
#     150                                           projection=projection,
#     151                                           map_style=map_style,
#     152                                           figsize=figsize,
#     153                                           aspectratio=aspectratio,
#     154                                           branch_width=line_width,
#     155                                           node_size=bus_size,
#     156                                           ext_grid_size=ext_grid_size,
#     157                                           node_color=bus_color,
#     158                                           branch_color=line_color,
#     159                                           trafo_color=trafo_color,
#     160                                           trafo3w_color=trafo3w_color,
#     161                                           ext_grid_color=ext_grid_color,
#     162                                           node_element=node_element,
#     163                                           branch_element=branch_element,
#     164                                           trans_element=trans_element,
#     165                                           trans3w_element=trans3w_element,
#     166                                           separator_element=separator_element,
#     167                                           branch_trace_func=create_line_trace,
#     168                                           node_trace_func=create_bus_trace,
#     169                                           hoverinfo_func=get_hoverinfo,
#     170                                           filename=filename,
#     171                                           auto_open=auto_open,
#     172                                           showlegend=showlegend)
#     173 if additional_traces:
#     174     if isinstance(additional_traces, dict):
#
# File c:\Python312\Lib\site-packages\pandapower\plotting\plotly\simple_plotly.py:197, in _simple_plotly_generic(net, respect_separators, use_branch_geodata, on_map, projection, map_style, figsize, aspectratio, branch_width, node_size, ext_grid_size, node_color, branch_color, trafo_color, trafo3w_color, ext_grid_color, node_element, branch_element, trans_element, trans3w_element, separator_element, branch_trace_func, node_trace_func, hoverinfo_func, filename, auto_open, showlegend)
#     190 def _simple_plotly_generic(net, respect_separators, use_branch_geodata, on_map, projection, map_style,
#     191                            figsize, aspectratio, branch_width, node_size, ext_grid_size, node_color,
#     192                            branch_color, trafo_color, trafo3w_color, ext_grid_color,
#    (...)
#     195                            hoverinfo_func, filename='temp-plot.html', auto_open=True,
#     196                            showlegend=True):
# --> 197     version_check()
#     198     settings = dict(on_map=on_map, projection=projection, map_style=map_style, figsize=figsize,
#     199                     aspectratio=aspectratio, filename=filename, auto_open=auto_open,
#     200                     showlegend=showlegend)
#     201     # create geocoord if none are available
#
# File c:\Python312\Lib\site-packages\pandapower\plotting\plotly\traces.py:40, in version_check()
#      38 def version_check():
#      39     if "plotly_version" not in locals() and "plotly_version" not in globals():
# ---> 40         raise UserWarning("You are trying to use plotly, which is not installed.\r\n"
#      41                           "Please upgrade your python-plotly installation, "
#      42                           "e.g., via pip install --upgrade plotly")
#      43     if version.parse(plotly_version) < version.parse("3.1.1"):
#      44         raise UserWarning(f"Your plotly version {plotly_version} is no longer supported.\r\n"
#      45                           "Please upgrade your python-plotly installation, "
#      46                           "e.g., via pip install --upgrade plotly")
#
# UserWarning: You are trying to use plotly, which is not installed.
# Please upgrade your python-plotly installation, e.g., via pip install --upgrade plotly
